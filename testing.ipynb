# %%
import torch
from misc import get_model_size
from models.hourglass.blocks import HourglassBlock
from models.utils import LayerNorm2d

# %load_ext autoreload
# %autoreload 2

# %%
test = torch.randn(size=(2, 256, 128, 128))
model = HourglassBlock()
model(test).shape
# Out:
# torch.Size([2, 256, 128, 128])

# %%
get_model_size(model)
# Out:
# Model size (bytes): 217705104
# Model size (MB): 207.62
# Model has 54,426,080 parameters
