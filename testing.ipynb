# %%
import torch
import torch.nn as nn
from models.hourglass.residual_module import ResidualModule
from models.hourglass.hourglass_module import HourglassModule
from models.utils import LayerNorm2d

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
test = torch.randn(size=(4, 256, 64, 64))
model = HourglassModule(normalization=LayerNorm2d)
model(test).shape
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 3
#       1 test = torch.randn(size=(4, 256, 64, 64))
#       2 model = HourglassModule(normalization=LayerNorm2d)
# ----> 3 model(test).shape
#
# File ~/Desktop/Projects/CornerNet2026/.venv/lib64/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/Projects/CornerNet2026/.venv/lib64/python3.13/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Desktop/Projects/CornerNet2026/models/hourglass/hourglass_module.py:3, in forward(self, x)
#       1 import torch
#       2 import torch.nn as nn
# ----> 3 from typing import Callable, Literal, Tuple
#       5 from .residual_module import *
#       8 def get_inner_layer(inner_module: Literal["single", "double", "triple"]) -> Callable:
#
# File ~/Desktop/Projects/CornerNet2026/.venv/lib64/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/Projects/CornerNet2026/.venv/lib64/python3.13/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Desktop/Projects/CornerNet2026/models/hourglass/hourglass_module.py:6, in forward(self, x)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Desktop/Projects/CornerNet2026/.venv/lib64/python3.13/site-packages/torch/nn/modules/module.py:1775, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1773     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1774 else:
# -> 1775     return self._call_impl(*args, **kwargs)
#
# File ~/Desktop/Projects/CornerNet2026/.venv/lib64/python3.13/site-packages/torch/nn/modules/module.py:1786, in Module._call_impl(self, *args, **kwargs)
#    1781 # If we don't have any hooks, we want to skip the rest of the logic in
#    1782 # this function, and just call forward.
#    1783 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1784         or _global_backward_pre_hooks or _global_backward_hooks
#    1785         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1786     return forward_call(*args, **kwargs)
#    1788 result = None
#    1789 called_always_called_hooks = set()
#
# File ~/Desktop/Projects/CornerNet2026/models/hourglass/residual_module.py:25, in ResidualModule.forward(self, x)
#      24 def forward(self, x):
# ---> 25     return x+self.block(x)
#
# RuntimeError: The size of tensor a (256) must match the size of tensor b (512) at non-singleton dimension 1
