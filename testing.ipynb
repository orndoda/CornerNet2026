# %%
import torch
import torch.nn as nn
import models.hourglass as hg
from models.utils import LayerNorm2d

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
test = torch.randn(size=(4, 256, 256, 256))
model = hg.ResidualModule(normalization=LayerNorm2d)
model(test).shape
# Out:
# torch.Size([4, 256, 256, 256])
