# %%
import torch
from misc import get_model_size
from models.hourglass.stacked_hourglass import *
from models.utils import LayerNorm2d

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
test = torch.randn(size=(2, 3, 1920, 1080))
model = StackedHourglass(in_channels=3, normalization=LayerNorm2d, interpolation_mode='bilinear')
model(test).shape
# Out:
# torch.Size([2, 64, 64, 64])

# %%
get_model_size(model)
# Out:
# Model size (bytes): 362010120
# Model size (MB): 345.24
# Model has 90,502,464 parameters
